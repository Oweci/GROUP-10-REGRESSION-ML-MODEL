# %%
#import all the necessary libraraies
import pandas as pd
import numpy as np

# %%
fpath = "/content/traffic_dataset_with_weekdays (1) (1).xlsx"
df = pd.read_excel(fpath)
df['ID'] = df.index
df = df.set_index('ID')
df.head()
# Out:
#              Timestamp Weekday  Cross 1   Cross 2   Cross 3   Cross 4  \
# ID
# 0  2024-01-01 00:00:00  Monday    105.0      48.0        30      62.0
# 1  2024-01-01 00:05:00  Monday     97.0      41.0        32      55.0
# 2  2024-01-01 00:10:00  Monday     76.0      47.0        44      58.0
# 3  2024-01-01 00:15:00  Monday     98.0      40.0        39      59.0
# 4  2024-01-01 00:20:00  Monday     87.0      41.0        47      49.0
#
#      Cross 5   Cross 6
# ID
# 0         31     110.0
# 1         42     103.0
# 2         40     100.0
# 3         43     104.0
# 4         35     112.0

# %%
df
# Out:
#                 Timestamp Weekday  Cross 1   Cross 2   Cross 3   Cross 4  \
# ID
# 0     2024-01-01 00:00:00  Monday    105.0      48.0        30      62.0
# 1     2024-01-01 00:05:00  Monday     97.0      41.0        32      55.0
# 2     2024-01-01 00:10:00  Monday     76.0      47.0        44      58.0
# 3     2024-01-01 00:15:00  Monday     98.0      40.0        39      59.0
# 4     2024-01-01 00:20:00  Monday     87.0      41.0        47      49.0
# ...                   ...     ...      ...       ...       ...       ...
# 11514 2024-02-23 23:35:00  Friday     55.0      33.0        31      46.0
# 11515 2024-02-23 23:40:00  Friday     45.0      29.0        18      57.0
# 11516 2024-02-23 23:45:00  Friday     46.0      21.0        22      39.0
# 11517 2024-02-23 23:50:00  Friday     50.0      20.0        18      47.0
# 11518 2024-02-23 23:55:00  Friday     60.0      30.0        10      42.0
#
#         Cross 5   Cross 6
# ID
# 0            31     110.0
# 1            42     103.0
# 2            40     100.0
# 3            43     104.0
# 4            35     112.0
# ...         ...       ...
# 11514        28      57.0
# 11515        29      69.0
# 11516        29      69.0
# 11517        31      57.0
# 11518        27      58.0
#
# [11519 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Timestamp     0
# Weekday       0
# Cross 1       0
#  Cross 2      0
#  Cross 3      0
#  Cross 4     14
#  Cross 5      0
#  Cross 6      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Timestamp', 'Weekday', 'Cross 1', ' Cross 2', ' Cross 3', ' Cross 4',
#        ' Cross 5', ' Cross 6'],
#       dtype='object')

# %%
df
# Out:
#                 Timestamp Weekday  Cross 1   Cross 2   Cross 3   Cross 4  \
# ID
# 0     2024-01-01 00:00:00  Monday    105.0      48.0        30      62.0
# 1     2024-01-01 00:05:00  Monday     97.0      41.0        32      55.0
# 2     2024-01-01 00:10:00  Monday     76.0      47.0        44      58.0
# 3     2024-01-01 00:15:00  Monday     98.0      40.0        39      59.0
# 4     2024-01-01 00:20:00  Monday     87.0      41.0        47      49.0
# ...                   ...     ...      ...       ...       ...       ...
# 11514 2024-02-23 23:35:00  Friday     55.0      33.0        31      46.0
# 11515 2024-02-23 23:40:00  Friday     45.0      29.0        18      57.0
# 11516 2024-02-23 23:45:00  Friday     46.0      21.0        22      39.0
# 11517 2024-02-23 23:50:00  Friday     50.0      20.0        18      47.0
# 11518 2024-02-23 23:55:00  Friday     60.0      30.0        10      42.0
#
#         Cross 5   Cross 6
# ID
# 0            31     110.0
# 1            42     103.0
# 2            40     100.0
# 3            43     104.0
# 4            35     112.0
# ...         ...       ...
# 11514        28      57.0
# 11515        29      69.0
# 11516        29      69.0
# 11517        31      57.0
# 11518        27      58.0
#
# [11519 rows x 8 columns]

# %%
df.shape
# len(df)
# Out:
# (11519, 8)

# %%
df.duplicated()
# Out:
# ID
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11514    False
# 11515    False
# 11516    False
# 11517    False
# 11518    False
# Length: 11519, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df.columns = df.columns.str.strip()
fig, ax = plt.subplots(figsize=(10,5))
x = df['Cross 4'].hist()
# ax.set(xlabel = "Cross 1", title = "distribution of traffic in cross 1")

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Weekday", y="Cross 2", data=df )

plt.title("Average Traffic at Cross 2")
plt.xlabel("Days of the Week")
plt.ylabel("Average Traffic (Cross 2)")
plt.show()

# %%
y = df['Cross 6']
x = df.drop( columns = ['Cross 6', 'Timestamp'])

# %%
num_cols = x.select_dtypes('number').columns

num_cols
# Out:
# Index(['Cross 1', 'Cross 2', 'Cross 3', 'Cross 4', 'Cross 5'], dtype='object')

# %%
cat_cols = x.select_dtypes('object').columns
cat_cols
# Out:
# Index(['Weekday'], dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

#imputing
numerical_meadian = SimpleImputer(strategy = 'median')

#scaling
scaler = StandardScaler()
#ordinal encoding
ordinal_encoder = OrdinalEncoder()

# %%
#creating transformers
num_transformer = Pipeline(steps = [
    ('imputer', numerical_meadian),
    ('scaler', scaler)
])

ordinal_transformer=Pipeline(
    steps=[('ord_enc',ordinal_encoder)]
    )

# %%
#combining transformers
df_traffic_preprocessor = ColumnTransformer(
     transformers =[
         ('numeric', num_transformer, num_cols),
         ('ordinal', ordinal_transformer,cat_cols)
     ],
     remainder='passthrough'
)

# %%
df_pipline = Pipeline(steps=[
    ('preprocessor', df_traffic_preprocessor),
    ('regressor', LinearRegression())
])

# %%
x_train, x_test, y_train, y_test = train_test_split( x,y, test_size = 0.3, random_state = 42)

# %%
#institiate the regsresoor
# linear_regressor = LinearRegression()

# %%
df_pipline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Cross 1', 'Cross 2', 'Cross 3', 'Cross 4', 'Cross 5'], dtype='object')),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('ord_enc',
#                                                                    OrdinalEncoder())]),
#                                                   Index(['Weekday'], dtype='object'))])),
#                 ('regressor', LinearRegression())])

# %% [markdown]
# prediction

# %%
y_predict = df_pipline.predict(x_test)
y_predict
# Out:
# array([  7.31312024, 136.08454221,  15.16328729, ..., 141.7146305 ,
#        108.65883397,  14.00689765])

# %%
r2 = r2_score(y_test, y_predict)
print("R²:", r2)
# Out:
# R²: 0.8540013437773113

# %%
print(mean_absolute_error(y_test, y_predict))
# Out:
# 17.949392956027342

# %%
print(mean_squared_error(y_test, y_predict))
# Out:
# 711.018527032773

# %%
print(df_pipline.score(x_train, y_train))
print(df_pipline.score(x_test, y_test))
# Out:
# 0.843308088803285
# 0.8540013437773113

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_predict)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# SECOND ALGORITHM(DECISION TREE REGRESSOR)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
df_pipline_tree = Pipeline(steps=[
    ('preprocessor', df_traffic_preprocessor),
    ('regressor', DecisionTreeRegressor())
])

# %%
df_pipline_tree.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Cross 1', 'Cross 2', 'Cross 3', 'Cross 4', 'Cross 5'], dtype='object')),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('ord_enc',
#                                                                    OrdinalEncoder())]),
#                                                   Index(['Weekday'], dtype='object'))])),
#                 ('regressor', DecisionTreeRegressor())])

# %%
y_predict_tree = df_pipline_tree.predict(x_test)
y_predict_tree
# Out:
# array([  0. , 190. ,  11. , ..., 146. , 136. ,   7.5])

# %%
r2 = r2_score(y_test, y_predict_tree)
print("R²:", r2)
# Out:
# R²: 0.8476499006480733

# %%
mean_absolute_error = mean_absolute_error(y_test, y_predict_tree)
print("Mean Absolute Error:", mean_absolute_error)
# Out:
# Mean Absolute Error: 15.253375771604938

# %%
#comparing the agorithms
print("Linear Regression R²:", r2_score(y_test, y_predict))
print("Decision Tree R²:", r2_score(y_test, y_predict_tree))
# Out:
# Linear Regression R²: 0.8540013437773113
# Decision Tree R²: 0.8476499006480733

# %%
#saving the model
import pickle
file_name_tree = "decision_tree_pipeline.sav"
file_name_linear = "linear_regression_pipeline.sav"

pickle.dump(df_pipline_tree, open(file_name_tree, 'wb'))
pickle.dump(df_pipline, open(file_name_linear, 'wb'))

# %%
load_tree_pipeline = pickle.load(open('decision_tree_pipeline.sav', 'rb'))

load_linear_pipeline = pickle.load(open('linear_regression_pipeline.sav', 'rb'))

print("Decision Tree Pipeline loaded successfully:", load_tree_pipeline)
print("Linear Regression Pipeline loaded successfully:", load_linear_pipeline)
# Out:
# Decision Tree Pipeline loaded successfully: Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Cross 1', 'Cross 2', 'Cross 3', 'Cross 4', 'Cross 5'], dtype='object')),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('ord_enc',
#                                                                    OrdinalEncoder())]),
#                                                   Index(['Weekday'], dtype='object'))])),
#                 ('regressor', DecisionTreeRegressor())])
# Linear Regression Pipeline loaded successfully: Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Cross 1', 'Cross 2', 'Cross 3', 'Cross 4', 'Cross 5'], dtype='object')),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('ord_enc',
#                                                                    OrdinalEncoder())]),
#                                                   Index(['Weekday'], dtype='object'))])),
#                 ('regressor', LinearRegression())])
